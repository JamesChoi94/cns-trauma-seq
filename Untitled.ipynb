# %%
import scvelo as scv
import scanpy as sc

# %%
counts = sc.read_10x_h5(filename='data/cellranger/Lindsay-Milich-14/outs/filtered_feature_bc_matrix.h5')

# %%
print(counts.shape)
# Out:
# (13906, 32285)

# %%
scv.set_figure_params()

# %%
counts
# Out:
# AnnData object with n_obs × n_vars = 13906 × 32285
#     var: 'gene_ids', 'feature_types', 'genome'

# %%
scv.pl.proportions(counts)
# Out:
# ---------------------------------------------------------------------------
# AxisError                                 Traceback (most recent call last)
# Cell In [10], line 1
# ----> 1 scv.pl.proportions(counts)
#
# File ~/miniconda3/envs/cns-trauma-seq/lib/python3.10/site-packages/scvelo/plotting/proportions.py:88, in proportions(adata, groupby, layers, highlight, add_labels_pie, add_labels_bar, fontsize, figsize, dpi, use_raw, show, save)
#      81 explode = [
#      82     0.1 if (layer_key == highlight or layer_key in highlight) else 0
#      83     for layer_key in layers_keys
#      84 ]
#      86 autopct = "%1.0f%%" if add_labels_pie else None
#      87 pie = ax.pie(
# ---> 88     np.mean(counts_layers, axis=1),
#      89     colors=colors,
#      90     explode=explode,
#      91     autopct=autopct,
#      92     shadow=True,
#      93     startangle=45,
#      94 )
#      95 if autopct is not None:
#      96     for pct, color in zip(pie[-1], colors):
#
# ...
